# %% [markdown]
# https://vincent.readthedocs.io/en/latest/quickstart.html

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
import vincent 

# %matplotlib inline

# %% [markdown]
# ### Data

# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

# %%
#Pandas
import pandas as pd

farm_1 = {'apples': 10, 'berries': 32, 'squash': 21, 'melons': 13, 'corn': 18}
farm_2 = {'apples': 15, 'berries': 43, 'squash': 17, 'melons': 10, 'corn': 22}
farm_3 = {'apples': 6, 'berries': 24, 'squash': 22, 'melons': 16, 'corn': 30}
farm_4 = {'apples': 12, 'berries': 30, 'squash': 15, 'melons': 9, 'corn': 15}

farm_data = [farm_1, farm_2, farm_3, farm_4]
farm_index = ['Farm 1', 'Farm 2', 'Farm 3', 'Farm 4']
df_farm = pd.DataFrame(farm_data, index=farm_index)

#As DataFrames
index_3 = multi_iter2.pop('index')
df_1 = pd.DataFrame(multi_iter2, index=index_3)
df_1 = df_1.reindex(columns=sorted(df_1.columns))

cat_4 = ['Metric_' + str(x) for x in range(0, 10, 1)]
index_4 = ['Data 1', 'Data 2', 'Data 3', 'Data 4']
data_3 = {}
for cat in cat_4:
    data_3[cat] = [random.randint(10, 100) for x in index_4]
df_2 = pd.DataFrame(data_3, index=index_4)

from pandas_datareader import data, wb

all_data = {}
for ticker in ['AAPL', 'GOOG', 'IBM', 'YHOO', 'MSFT']:
    all_data[ticker] = data.DataReader(ticker, 'yahoo', '1/1/2010', '1/1/2013')
price = pd.DataFrame({tic: data['Adj Close']
                      for tic, data in all_data.items()})

#Map Data Binding
import json
import pandas as pd
#Map the county codes we have in our geometry to those in the
#county_data file, which contains additional rows we don't need
with open('us_counties.topo.json', 'r') as f:
    get_id = json.load(f)

#A little FIPS code munging
new_geoms = []
for geom in get_id['objects']['us_counties.geo']['geometries']:
    geom['properties']['FIPS'] = int(geom['properties']['FIPS'])
    new_geoms.append(geom)

get_id['objects']['us_counties.geo']['geometries'] = new_geoms

with open('us_counties.topo.json', 'w') as f:
    json.dump(get_id, f)

#Grab the FIPS codes and load them into a dataframe
geometries = get_id['objects']['us_counties.geo']['geometries']
county_codes = [x['properties']['FIPS'] for x in geometries]
county_df = pd.DataFrame({'FIPS': county_codes}, dtype=str)
county_df = county_df.astype(int)

#Read into Dataframe, cast to string for consistency
df = pd.read_csv('data/us_county_data.csv', na_values=[' '])
df['FIPS_Code'] = df['FIPS'].astype(str)

#Perform an inner join, pad NA's with data from nearest county
merged = pd.merge(df, county_df, on='FIPS', how='inner')
merged = merged.fillna(method='pad')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-361feab646e7> in <module>()
#      55 #Map the county codes we have in our geometry to those in the
#      56 #county_data file, which contains additional rows we don't need
# ---> 57 with open('us_counties.topo.json', 'r') as f:
#      58     get_id = json.load(f)
#      59
#
# FileNotFoundError: [Errno 2] No such file or directory: 'us_counties.topo.json'

# %%
vincent.core.initialize_notebook()

bar = vincent.Bar(list_data)
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %%
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
# Out:
# <div id="viseef7af10edef4fd29e01caa77c87875e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Index", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "data", "idx": 0, "val": 88}, {"col": "data", "idx": 1, "val": 61}, {"col": "data", "idx": 2, "val": 32}, {"col": "data", "idx": 3, "val": 15}, {"col": "data", "idx": 4, "val": 62}, {"col": "data", "idx": 5, "val": 43}, {"col": "data", "idx": 6, "val": 62}, {"col": "data", "idx": 7, "val": 62}, {"col": "data", "idx": 8, "val": 84}, {"col": "data", "idx": 9, "val": 48}, {"col": "data", "idx": 10, "val": 33}, {"col": "data", "idx": 11, "val": 75}, {"col": "data", "idx": 12, "val": 68}, {"col": "data", "idx": 13, "val": 53}, {"col": "data", "idx": 14, "val": 43}, {"col": "data", "idx": 15, "val": 65}, {"col": "data", "idx": 16, "val": 99}, {"col": "data", "idx": 17, "val": 41}, {"col": "data", "idx": 18, "val": 94}, {"col": "data", "idx": 19, "val": 79}, {"col": "data", "idx": 20, "val": 81}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "width": {"band": true, "offset": -1, "scale": "x"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "rect"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "ordinal", "zero": false}, {"domain": {"data": "stats", "field": "sum"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#viseef7af10edef4fd29e01caa77c87875e"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
from vincent import AxisProperties, PropertySet, ValueRef
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
#rotate x axis labels
ax = AxisProperties(
         labels = PropertySet(angle=ValueRef(value=90)))
bar.axes[0].properties = ax

# %%
line = vincent.Line(list_data)
line.axis_titles(x='Index', y='Value')
# Out:
# <div id="vis79b782b78a194510ae93669b6537b2b2"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Index", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "data", "idx": 0, "val": 10}, {"col": "data", "idx": 1, "val": 20}, {"col": "data", "idx": 2, "val": 30}, {"col": "data", "idx": 3, "val": 20}, {"col": "data", "idx": 4, "val": 15}, {"col": "data", "idx": 5, "val": 30}, {"col": "data", "idx": 6, "val": 45}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}]}, "marks": [{"properties": {"enter": {"stroke": {"field": "data.col", "scale": "color"}, "strokeWidth": {"value": 2}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "data.val", "scale": "y"}}}, "type": "line"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "linear"}, {"domain": {"data": "table", "field": "data.val"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis79b782b78a194510ae93669b6537b2b2"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Categories')
# Out:
# <div id="vis3f5baa0454c34f9586740ca2406b4b7f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Index", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "y1", "idx": 0, "val": 88}, {"col": "y1", "idx": 1, "val": 61}, {"col": "y1", "idx": 2, "val": 32}, {"col": "y1", "idx": 3, "val": 15}, {"col": "y1", "idx": 4, "val": 62}, {"col": "y1", "idx": 5, "val": 43}, {"col": "y1", "idx": 6, "val": 62}, {"col": "y1", "idx": 7, "val": 62}, {"col": "y1", "idx": 8, "val": 84}, {"col": "y1", "idx": 9, "val": 48}, {"col": "y1", "idx": 10, "val": 33}, {"col": "y1", "idx": 11, "val": 75}, {"col": "y1", "idx": 12, "val": 68}, {"col": "y1", "idx": 13, "val": 53}, {"col": "y1", "idx": 14, "val": 43}, {"col": "y1", "idx": 15, "val": 65}, {"col": "y1", "idx": 16, "val": 99}, {"col": "y1", "idx": 17, "val": 41}, {"col": "y1", "idx": 18, "val": 94}, {"col": "y1", "idx": 19, "val": 79}, {"col": "y1", "idx": 20, "val": 81}, {"col": "y2", "idx": 0, "val": 94}, {"col": "y2", "idx": 1, "val": 72}, {"col": "y2", "idx": 2, "val": 35}, {"col": "y2", "idx": 3, "val": 48}, {"col": "y2", "idx": 4, "val": 98}, {"col": "y2", "idx": 5, "val": 77}, {"col": "y2", "idx": 6, "val": 18}, {"col": "y2", "idx": 7, "val": 100}, {"col": "y2", "idx": 8, "val": 96}, {"col": "y2", "idx": 9, "val": 23}, {"col": "y2", "idx": 10, "val": 43}, {"col": "y2", "idx": 11, "val": 87}, {"col": "y2", "idx": 12, "val": 11}, {"col": "y2", "idx": 13, "val": 45}, {"col": "y2", "idx": 14, "val": 74}, {"col": "y2", "idx": 15, "val": 35}, {"col": "y2", "idx": 16, "val": 93}, {"col": "y2", "idx": 17, "val": 38}, {"col": "y2", "idx": 18, "val": 49}, {"col": "y2", "idx": 19, "val": 49}, {"col": "y2", "idx": 20, "val": 55}, {"col": "y3", "idx": 0, "val": 69}, {"col": "y3", "idx": 1, "val": 37}, {"col": "y3", "idx": 2, "val": 44}, {"col": "y3", "idx": 3, "val": 88}, {"col": "y3", "idx": 4, "val": 36}, {"col": "y3", "idx": 5, "val": 64}, {"col": "y3", "idx": 6, "val": 62}, {"col": "y3", "idx": 7, "val": 94}, {"col": "y3", "idx": 8, "val": 31}, {"col": "y3", "idx": 9, "val": 14}, {"col": "y3", "idx": 10, "val": 18}, {"col": "y3", "idx": 11, "val": 76}, {"col": "y3", "idx": 12, "val": 11}, {"col": "y3", "idx": 13, "val": 54}, {"col": "y3", "idx": 14, "val": 51}, {"col": "y3", "idx": 15, "val": 50}, {"col": "y3", "idx": 16, "val": 60}, {"col": "y3", "idx": 17, "val": 80}, {"col": "y3", "idx": 18, "val": 43}, {"col": "y3", "idx": 19, "val": 89}, {"col": "y3", "idx": 20, "val": 68}, {"col": "y4", "idx": 0, "val": 41}, {"col": "y4", "idx": 1, "val": 18}, {"col": "y4", "idx": 2, "val": 75}, {"col": "y4", "idx": 3, "val": 71}, {"col": "y4", "idx": 4, "val": 81}, {"col": "y4", "idx": 5, "val": 37}, {"col": "y4", "idx": 6, "val": 33}, {"col": "y4", "idx": 7, "val": 70}, {"col": "y4", "idx": 8, "val": 62}, {"col": "y4", "idx": 9, "val": 43}, {"col": "y4", "idx": 10, "val": 43}, {"col": "y4", "idx": 11, "val": 26}, {"col": "y4", "idx": 12, "val": 90}, {"col": "y4", "idx": 13, "val": 70}, {"col": "y4", "idx": 14, "val": 27}, {"col": "y4", "idx": 15, "val": 25}, {"col": "y4", "idx": 16, "val": 80}, {"col": "y4", "idx": 17, "val": 52}, {"col": "y4", "idx": 18, "val": 72}, {"col": "y4", "idx": 19, "val": 84}, {"col": "y4", "idx": 20, "val": 27}]}], "height": 500, "legends": [{"fill": "color", "offset": 0, "properties": {}, "title": "Categories"}], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}]}, "marks": [{"properties": {"enter": {"stroke": {"field": "data.col", "scale": "color"}, "strokeWidth": {"value": 2}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "data.val", "scale": "y"}}}, "type": "line"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "linear"}, {"domain": {"data": "table", "field": "data.val"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "o ...
#          chart({el: "#vis3f5baa0454c34f9586740ca2406b4b7f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
line = vincent.Line(price[['GOOG', 'AAPL']])
line.axis_titles(x='Date', y='Price')
line.legend(title='GOOG vs AAPL')
# Out:
# <div id="vis5a9b45ad10c34a618fd91fe5598a3417"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Date", "type": "x"}, {"scale": "y", "title": "Price", "type": "y"}], "data": [{"name": "table", "values": [{"col": "GOOG", "idx": 1262584800000, "val": 313.062468}, {"col": "AAPL", "idx": 1262584800000, "val": 27.727039}, {"col": "GOOG", "idx": 1262671200000, "val": 311.683844}, {"col": "AAPL", "idx": 1262671200000, "val": 27.774976000000002}, {"col": "GOOG", "idx": 1262757600000, "val": 303.826685}, {"col": "AAPL", "idx": 1262757600000, "val": 27.333178000000004}, {"col": "GOOG", "idx": 1262844000000, "val": 296.753749}, {"col": "AAPL", "idx": 1262844000000, "val": 27.28265}, {"col": "GOOG", "idx": 1262930400000, "val": 300.709808}, {"col": "AAPL", "idx": 1262930400000, "val": 27.464034}, {"col": "GOOG", "idx": 1263189600000, "val": 300.255255}, {"col": "AAPL", "idx": 1263189600000, "val": 27.221758}, {"col": "GOOG", "idx": 1263276000000, "val": 294.945572}, {"col": "AAPL", "idx": 1263276000000, "val": 26.91211}, {"col": "
 10, "val": 39}, {"col": "y3", "idx": 11, "val": 59}, {"col": "y3", "idx": 12, "val": 59}, {"col": "y3", "idx": 13, "val": 50}, {"col": "y3", "idx": 14, "val": 76}, {"col": "y3", "idx": 15, "val": 87}, {"col": "y3", "idx": 16, "val": 63}, {"col": "y3", "idx": 17, "val": 79}, {"col": "y3", "idx": 18, "val": 73}, {"col": "y3", "idx": 19, "val": 91}, {"col": "y3", "idx": 20, "val": 39}, {"col": "y4", "idx": 0, "val": 20}, {"col": "y4", "idx": 1, "val": 98}, {"col": "y4", "idx": 2, "val": 77}, {"col": "y4", "idx": 3, "val": 47}, {"col": "y4", "idx": 4, "val": 47}, {"col": "y4", "idx": 5, "val": 26}, {"col": "y4", "idx": 6, "val": 84}, {"col": "y4", "idx": 7, "val": 12}, {"col": "y4", "idx": 8, "val": 32}, {"col": "y4", "idx": 9, "val": 52}, {"col": "y4", "idx": 10, "val": 17}, {"col": "y4", "idx": 11, "val": 100}, {"col": "y4", "idx": 12, "val": 31}, {"col": "y4", "idx": 13, "val": 89}, {"col": "y4", "idx": 14, "val": 39}, {"col": "y4", "idx": 15, "val": 93}, {"col": "y4", "idx": 16, "val": 59}, {"col": "y4", "idx": 17, "val": 10}, {"col": "y4", "idx": 18, "val": 22}, {"col": "y4", "idx": 19, "val": 37}, {"col": "y4", "idx": 20, "val": 83}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [{"fill": "color", "offset": 0, "properties": {}, "title": "Categories"}], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "interpolate": {"value": "monotone"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "area"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "ra ...
#          chart({el: "#vis73cc9f8593e74de9aa28116fdd10cdf2"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
stacked = vincent.StackedArea(df_1)
stacked.axis_titles(x='Index', y='Value')
stacked.legend(title='Categories')
stacked.colors(brew='Spectral')
# Out:
# <div id="vis15f0d11165314148b5700fc48f6ae221"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Index", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "y0", "idx": 1, "val": 100}, {"col": "y1", "idx": 1, "val": 11}, {"col": "y2", "idx": 1, "val": 65}, {"col": "y3", "idx": 1, "val": 20}, {"col": "y4", "idx": 1, "val": 60}, {"col": "y5", "idx": 1, "val": 40}, {"col": "y6", "idx": 1, "val": 10}, {"col": "y7", "idx": 1, "val": 88}, {"col": "y8", "idx": 1, "val": 30}, {"col": "y9", "idx": 1, "val": 31}, {"col": "y0", "idx": 2, "val": 64}, {"col": "y1", "idx": 2, "val": 15}, {"col": "y2", "idx": 2, "val": 66}, {"col": "y3", "idx": 2, "val": 32}, {"col": "y4", "idx": 2, "val": 11}, {"col": "y5", "idx": 2, "val": 41}, {
O", "idx": 1263189600000, "val": 16.74}, {"col": "AAPL", "idx": 1263276000000, "val": 26.91211}, {"col": "GOOG", "idx": 1263276000000, "val": 294.945572}, {"col": "IBM", "idx": 1263276000000, "val": 109.77324499999999}, {"col": "MSFT", "idx": 1263276000000, "val": 24.828866}, {"col": "YHOO", "idx": 1263276000000, "val": 16.68}, {"col": "AAPL", "idx": 1263362400000, "val": 27.29172}, {"col": "GOOG", "idx": 1263362400000, "val": 293.252243}, {"col": "IBM", "idx": 1263362400000, "val": 109.53773500000001}, {"col": "MSFT", "idx": 1263362400000, "val": 25.060064}, {"col": "YHOO", "idx": 1263362400000, "val": 16.9}, {"col": "AAPL", "idx": 1263448800000, "val": 27.133657}, {"col": "GOOG", "idx": 1263448800000, "val": 294.630868}, {"col": "IBM", "idx": 1263448800000, "val": 111.287245}, {"col": "MSFT", "idx": 1263448800000, "val": 25.563741}, {"col": "YHOO", "idx": 1263448800000, "val": 17.120001000000002}, {"col": "AAPL", "idx": 1263535200000, "val": 26.680197999999997}, {"col": "GOOG", "idx": 1263535200000, "val": 289.710772}, {"col": "IBM", "idx": 1263535200000, "val": 110.841458}, {"col": "MSFT", "idx": 1263535200000, "val": 25.481172}, {"col": "YHOO", "idx": 1263535200000, "val": 16.82}, {"col": "AAPL", "idx": 1263880800000, "val": 27.860484999999997}, {"col": "GOOG", "idx": 1263880800000, "val": 293.516976}, {"col": "IBM", "idx": 1263880800000, "val": 112.82647800000001}, {"col": "MSFT", "idx": 1263880800000, "val": 25.67934}, {"col": "YHOO", "idx": 1263880800000, "val": 16.75}, {"col": "AAPL", "idx": 1263967200000, "val": 27.431644}, {"col": "GOOG", "idx": 1263967200000, "val": 289.915587}, {"col": "IBM", "idx": 1263967200000, "val": 109.554561}, {"col": "MSFT", "idx": 1263967200000, "val": 25.258232}, {"col": "YHOO", "idx": 1263967200000, "val": 16.379998999999998}, {"col": "AAPL", "idx": 1264053600000, "val": 26.957455}, {"col": "GOOG", "idx": 1264053600000, "val": 291.199286}, {"col": "IBM", "idx": 1264053600000, "val": 108.503173}, {"col": "MSFT", "idx": 1264053600000, "val": 24.779325}, {"col": "YHOO", "idx": 1264053600000, "val": 16.200001}, {"col": "AAPL", "idx": 1264140000000, "val": 25.620401}, { ...

# %%
stack = vincent.StackedBar(df_2)
stack.legend(title='Categories')
# Out:
# <div id="vis82e51be7b3de4414b6cbbd93481b975d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "type": "x"}, {"scale": "y", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Metric_0", "idx": "Data 1", "val": 97}, {"col": "Metric_1", "idx": "Data 1", "val": 73}, {"col": "Metric_2", "idx": "Data 1", "val": 52}, {"col": "Metric_3", "idx": "Data 1", "val": 29}, {"col": "Metric_4", "idx": "Data 1", "val": 35}, {"col": "Metric_5", "idx": "Data 1", "val": 18}, {"col": "Metric_6", "idx": "Data 1", "val": 35}, {"col": "Metric_7", "idx": "Data 1", "val": 25}, {"col": "Metric_8", "idx": "Data 1", "val": 40}, {"col": "Metric_9", "idx": "Data 1", "val": 37}, {"col": "Metric_0", "idx": "Data 2", "val": 82}, {"col": "Metric_1", "idx": "Data 2", "val": 25}, {"col": "Metric_2", "idx": "Data 2", "val": 47}, {"col": "Metric_3", "idx": "Data 2", "val": 31}, {"col": "Metric_4", "idx": "Data 2", "val": 73}, {"col": "Metric_5", "idx": "Data 2", "val": 28}, {"col": "Metric_6", "idx": "Data 2", "val": 69}, {"col": "Metric_7", "idx": "Data 2", "val": 87}, {"col": "Metric_8", "idx": "Data 2", "val": 94}, {"col": "Metric_9", "idx": "Data 2", "val": 35}, {"col": "Metric_0", "idx": "Data 3", "val": 92}, {"col": "Metric_1", "idx": "Data 3", "val": 27}, {"col": "Metric_2", "idx": "Data 3", "val": 15}, {"col": "Metric_3", "idx": "Data 3", "val": 43}, {"col": "Metric_4", "idx": "Data 3", "val": 19}, {"col": "Metric_5", "idx": "Data 3", "val": 84}, {"col": "Metric_6", "idx": "Data 3", "val": 58}, {"col": "Metric_7", "idx": "Data 3", "val": 64}, {"col": "Metric_8", "idx": "Data 3", "val": 52}, {"col": "Metric_9", "idx": "Data 3", "val": 30}, {"col": "Metric_0", "idx": "Data 4", "val": 43}, {"col": "Metric_1", "idx": "Data 4", "val": 74}, {"col": "Metric_2", "idx": "Data 4", "val": 13}, {"col": "Metric_3", "idx": "Data 4", "val": 89}, {"col": "Metric_4", "idx": "Data 4", "val": 94}, {"col": "Metric_5", "idx": "Data 4", "val": 43}, {"col": "Metric_6", "idx": "Data 4", "val": 76}, {"col": "Metric_7", "idx": "Data 4", "val": 77}, {"col": "Metric_8", "idx": "Data 4", "val": 34}, {"col": "Metric_9", "idx": "Data 4", "val": 65}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [{"fill": "color", "offset": 0, "properties": {}, "title": "Categories"}], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "width": {"band": true, "offset": -1, "scale": "x"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "rect"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "ordinal", "zero": false}, {"domain": {"data": "stats", "field": "sum"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis82e51be7b3de4414b6cbbd93481b975d"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
